# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import keras
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras import applications, callbacks, optimizers
from keras.layers import *
from keras.layers.advanced_activations import ELU, LeakyReLU, PReLU, ReLU
from keras.utils.vis_utils import plot_model
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras.layers import (Activation, Add, AveragePooling2D,
                                     BatchNormalization, Conv2D,
                                     Conv2DTranspose, Dropout, Input,
                                     MaxPooling2D, Permute, Reshape,
                                     SpatialDropout2D, UpSampling2D,
                                     ZeroPadding2D, add, concatenate)
from tensorflow.keras.models import Model, model_from_json
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm

# %%
# Loading Training and Testing Set

X = []
Y = []
for i in range(612):
      path = '/content/drive/MyDrive/GNR_PROJECT/TIF/Original/'+ str(i+1)+'.tif'
      img = cv2.imread(path,1)
      resized_img = cv2.resize(img,(256, 192), interpolation = cv2.INTER_CUBIC)
      X.append(resized_img)
      
for i in range(612):
      path2 = '/content/drive/MyDrive/GNR_PROJECT/TIF/GroundTruth/' + str(i+1)+'.tif'
      msk = cv2.imread(path2,0)
      resized_msk = cv2.resize(msk,(256, 192), interpolation = cv2.INTER_CUBIC)
      Y.append(resized_msk)

# %% [markdown]
# Some images from dataset and mean analysis

# %%
# %matplotlib inline
plt.imshow(X[0], interpolation='nearest')
plt.show()
plt.imshow(X[44], interpolation='nearest')
plt.show()
plt.imshow(X[115], interpolation='nearest')
plt.show()

# %%
def conv2d_bn(x, filters, num_row, num_col, padding='same', strides=(1, 1), activation='relu', name=None):
      '''
      2D Convolutional layers
      
      Arguments:
          x {keras layer} -- input layer 
          filters {int} -- number of filters
          num_row {int} -- number of rows in filters
          num_col {int} -- number of columns in filters
      
      Keyword Arguments:
          padding {str} -- mode of padding (default: {'same'})
          strides {tuple} -- stride of convolution operation (default: {(1, 1)})
          activation {str} -- activation function (default: {'relu'})
          name {str} -- name of the layer (default: {None})
      
      Returns:
          [keras layer] -- [output layer]
      '''

      x = Conv2D(filters, (num_row, num_col), strides=strides, padding=padding, use_bias=False)(x)
      x = BatchNormalization(axis=3, scale=False)(x)

      if(activation == None):
          return x

      x = Activation(activation, name=name)(x)

      return x

# %%
def trans_conv2d_bn(x, filters, num_row, num_col, padding='same', strides=(2, 2), name=None):
      '''
      2D Transposed Convolutional layers
      
      Arguments:
          x {keras layer} -- input layer 
          filters {int} -- number of filters
          num_row {int} -- number of rows in filters
          num_col {int} -- number of columns in filters
      
      Keyword Arguments:
          padding {str} -- mode of padding (default: {'same'})
          strides {tuple} -- stride of convolution operation (default: {(2, 2)})
          name {str} -- name of the layer (default: {None})
      
      Returns:
          [keras layer] -- [output layer]
      '''

      x = Conv2DTranspose(filters, (num_row, num_col), strides=strides, padding=padding)(x)
      x = BatchNormalization(axis=3, scale=False)(x)
      
      return x

# %%
def DCBlock(U, inp, alpha = 1.67):
      '''
      DC Block
      
      Arguments:
          U {int} -- Number of filters in a corrsponding UNet stage
          inp {keras layer} -- input layer 
      
      Returns:
          [keras layer] -- [output layer]
      '''

      W = alpha * U

      #shortcut = inp

      #shortcut = conv2d_bn(shortcut, int(W*0.167) + int(W*0.333) +
    #                      int(W*0.5), 1, 1, activation=None, padding='same')

      conv3x3_1 = conv2d_bn(inp, int(W*0.167), 3, 3,
                          activation='relu', padding='same')

      conv5x5_1 = conv2d_bn(conv3x3_1, int(W*0.333), 3, 3,
                          activation='relu', padding='same')

      conv7x7_1 = conv2d_bn(conv5x5_1, int(W*0.5), 3, 3,
                          activation='relu', padding='same')

      out1 = concatenate([conv3x3_1, conv5x5_1, conv7x7_1], axis=3)
      out1 = BatchNormalization(axis=3)(out1)
      
      conv3x3_2 = conv2d_bn(inp, int(W*0.167), 3, 3,
                          activation='relu', padding='same')

      conv5x5_2 = conv2d_bn(conv3x3_2, int(W*0.333), 3, 3,
                          activation='relu', padding='same')

      conv7x7_2 = conv2d_bn(conv5x5_2, int(W*0.5), 3, 3,
                          activation='relu', padding='same')
      out2 = concatenate([conv3x3_2, conv5x5_2, conv7x7_2], axis=3)
      out2 = BatchNormalization(axis=3)(out2)

      out = add([out1, out2])
      out = Activation('relu')(out)
      out = BatchNormalization(axis=3)(out)

      return out

# %%
def ResPath(filters, length, inp):
      '''
      ResPath
      
      Arguments:
          filters {int} -- [description]
          length {int} -- length of ResPath
          inp {keras layer} -- input layer 
      
      Returns:
          [keras layer] -- [output layer]
      '''

      shortcut = inp
      shortcut = conv2d_bn(shortcut, filters, 1, 1,
                          activation=None, padding='same')

      out = conv2d_bn(inp, filters, 3, 3, activation='relu', padding='same')

      out = add([shortcut, out])
      out = Activation('relu')(out)
      out = BatchNormalization(axis=3)(out)

      for i in range(length-1):

          shortcut = out
          shortcut = conv2d_bn(shortcut, filters, 1, 1,
                              activation=None, padding='same')

          out = conv2d_bn(out, filters, 3, 3, activation='relu', padding='same')

          out = add([shortcut, out])
          out = Activation('relu')(out)
          out = BatchNormalization(axis=3)(out)

      return out

# %%
def DCUNet(height, width, channels):
      '''
      DC-UNet
      
      Arguments:
          height {int} -- height of image 
          width {int} -- width of image 
          n_channels {int} -- number of channels in image
      
      Returns:
          [keras model] -- MultiResUNet model
      '''

      inputs = Input((height, width, channels))

      dcblock1 = DCBlock(32, inputs)
      pool1 = MaxPooling2D(pool_size=(2, 2))(dcblock1)
      dcblock1 = ResPath(32, 4, dcblock1)

      dcblock2 = DCBlock(32*2, pool1)
      pool2 = MaxPooling2D(pool_size=(2, 2))(dcblock2)
      dcblock2 = ResPath(32*2, 3, dcblock2)

      dcblock3 = DCBlock(32*4, pool2)
      pool3 = MaxPooling2D(pool_size=(2, 2))(dcblock3)
      dcblock3 = ResPath(32*4, 2, dcblock3)

      dcblock4 = DCBlock(32*8, pool3)
      pool4 = MaxPooling2D(pool_size=(2, 2))(dcblock4)
      dcblock4 = ResPath(32*8, 1, dcblock4)

      dcblock5 = DCBlock(32*16, pool4)

      up6 = concatenate([Conv2DTranspose(
          32*8, (2, 2), strides=(2, 2), padding='same')(dcblock5), dcblock4], axis=3)
      dcblock6 = DCBlock(32*8, up6)

      up7 = concatenate([Conv2DTranspose(
          32*4, (2, 2), strides=(2, 2), padding='same')(dcblock6), dcblock3], axis=3)
      dcblock7 = DCBlock(32*4, up7)

      up8 = concatenate([Conv2DTranspose(
          32*2, (2, 2), strides=(2, 2), padding='same')(dcblock7), dcblock2], axis=3)
      dcblock8 = DCBlock(32*2, up8)

      up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(
          2, 2), padding='same')(dcblock8), dcblock1], axis=3)
      dcblock9 = DCBlock(32, up9)

      conv10 = conv2d_bn(dcblock9, 1, 1, 1, activation='sigmoid')
      
      model = Model(inputs=[inputs], outputs=[conv10])
      
      return model

# %%
# different loss functions
  def dice_coef(y_true, y_pred):
      smooth = 1.0  #0.0
      y_true_f = K.flatten(y_true)
      y_pred_f = K.flatten(y_pred)
      intersection = K.sum(y_true_f * y_pred_f)
      return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %%
def jacard(y_true, y_pred):

      y_true_f = K.flatten(y_true)
      y_pred_f = K.flatten(y_pred)
      intersection = K.sum ( y_true_f * y_pred_f)
      union = K.sum ( y_true_f + y_pred_f - y_true_f * y_pred_f)

      return intersection/union

# %%
  def dice_coef_loss(y_true,y_pred):
      return 1 - dice_coef(y_true,y_pred)

# %%
  def iou_loss(y_true,y_pred):
      return 1 - jacard(y_true, y_pred)

# %%
  def tversky(y_true, y_pred):
      y_true_pos = K.flatten(y_true)
      y_pred_pos = K.flatten(y_pred)
      true_pos = K.sum(y_true_pos * y_pred_pos)
      false_neg = K.sum(y_true_pos * (1-y_pred_pos))
      false_pos = K.sum((1-y_true_pos)*y_pred_pos)
      alpha = 0.75
      smooth = 1
      return (true_pos + smooth)/(true_pos + alpha*false_neg + (1-alpha)*false_pos + smooth)

# %%
 def tversky_loss(y_true, y_pred):
      return 1 - tversky(y_true,y_pred)

# %%
 def focal_tversky(y_true,y_pred):
      pt_1 = tversky(y_true, y_pred)
      gamma = 0.75
      return K.pow((1-pt_1), gamma)

# %%
with tf.device('/device:GPU:0'):

  X = np.array(X)
  Y = np.array(Y)

  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)
  Y_train = Y_train.reshape((Y_train.shape[0],Y_train.shape[1],Y_train.shape[2],1))
  Y_test = Y_test.reshape((Y_test.shape[0],Y_test.shape[1],Y_test.shape[2],1))


  X_train = X_train / 255
  X_test = X_test / 255
  Y_train = Y_train / 255
  Y_test = Y_test / 255

  Y_train = np.round(Y_train,0)	
  Y_test = np.round(Y_test,0)	

  print(X_train.shape)
  print(Y_train.shape)
  print(X_test.shape)
  print(Y_test.shape)

  # Training and Testing

  def saveModel(model):
      model_json = model.to_json()
      try:
          os.makedirs('models')
      except:
          pass
      fp = open('modelP.json','w')
      fp.write(model_json)
      model.save('modelW.h5')


  def evaluateModel(model, X_test, Y_test, batchSize):
      try:
          os.makedirs('results')
      except:
          pass 
      yp = model.predict(x=X_test, batch_size=batchSize, verbose=1)
      yp = np.round(yp,0)
      
      for i in range(10):

          plt.figure(figsize=(20,10))
          plt.subplot(1,3,1)
          plt.imshow(X_test[i])
          plt.title('Input')
          plt.subplot(1,3,2)
          plt.imshow(Y_test[i].reshape(Y_test[i].shape[0],Y_test[i].shape[1]))
          plt.title('Ground Truth')
          plt.subplot(1,3,3)
          plt.imshow(yp[i].reshape(yp[i].shape[0],yp[i].shape[1]))
          plt.title('Prediction')

          intersection = yp[i].ravel() * Y_test[i].ravel()
          union = yp[i].ravel() + Y_test[i].ravel() - intersection

          jacard = (np.sum(intersection)/np.sum(union))  
          plt.suptitle('Jacard Index'+ str(np.sum(intersection)) +'/'+ str(np.sum(union)) +'='+str(jacard))

          plt.savefig('results/'+str(i)+'.png',format='png')
          plt.close()
      
      jacard = 0
      dice = 0
      
      
      for i in range(len(Y_test)):
          yp_2 = yp[i].ravel()
          y2 = Y_test[i].ravel()
          
          intersection = yp_2 * y2
          union = yp_2 + y2 - intersection

          jacard += (np.sum(intersection)/np.sum(union))  

          dice += (2. * np.sum(intersection) ) / (np.sum(yp_2) + np.sum(y2))

      
      jacard /= len(Y_test)
      dice /= len(Y_test)
      


      print('Jacard Index : '+str(jacard))
      print('Dice Coefficient : '+str(dice))
      

      fp = open('log2.txt','a')
      fp.write(str(jacard)+'\n')
      fp.close()

      fp = open('best2.txt','r')
      best = fp.read()
      fp.close()

      if(jacard>float(best)):
          print('***********************************************')
          print('Jacard Index improved from '+str(best)+' to '+str(jacard))
          print('***********************************************')
          fp = open('best2.txt','w')
          fp.write(str(jacard))
          fp.close()

          saveModel(model)


  def trainStep(model, X_train, Y_train, X_test, Y_test, epochs, batchSize):

      
      for epoch in range(epochs):
          print('Epoch : {}'.format(epoch+1))
          model.fit(x=X_train, y=Y_train, batch_size=batchSize, epochs=1, verbose=1)     

          evaluateModel(model,X_test, Y_test,batchSize)

      return model 


  model = DCUNet(height=192, width=256, channels=3)

  model.compile(optimizer='adam', loss=focal_tversky, metrics=[dice_coef, jacard, 'accuracy'])
  #binary_crossentropy loss
  model.summary()
  saveModel(model)

  fp = open('log2.txt','w')
  fp.close()
  fp = open('best2.txt','w')
  fp.write('-1.0')
  fp.close()
      
  trainStep(model, X_train, Y_train, X_test, Y_test, epochs=50, batchSize=4)
# Out:
# (489, 192, 256, 3)
# (489, 192, 256, 1)
# (123, 192, 256, 3)
# (123, 192, 256, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 192, 256, 3  0           []
#                                 )]
#
#  conv2d_75 (Conv2D)             (None, 192, 256, 8)  216         ['input_2[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 192, 256, 8)  216         ['input_2[0][0]']
#
#  batch_normalization_112 (Batch  (None, 192, 256, 8)  24         ['conv2d_75[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 192, 256, 8)  24         ['conv2d_78[0][0]']
#  Normalization)
#
#  activation_84 (Activation)     (None, 192, 256, 8)  0           ['batch_normalization_112[0][0]']
#
#  activation_87 (Activation)     (None, 192, 256, 8)  0           ['batch_normalization_116[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 192, 256, 17  1224        ['activation_84[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 192, 256, 17  1224        ['activation_87[0][0]']
#                                 )
#
#  batch_normalization_113 (Batch  (None, 192, 256, 17  51         ['conv2d_76[0][0]']
#  Normalization)                 )
#
#  batch_normalization_117 (Batch  (None, 192, 256, 17  51         ['conv2d_79[0][0]']
#  Normalization)                 )
#
#  activation_85 (Activation)     (None, 192, 256, 17  0           ['batch_normalization_113[0][0]']
#                                 )
#
#  activation_88 (Activation)     (None, 192, 256, 17  0           ['batch_normalization_117[0][0]']
#                                 )
#
#  conv2d_77 (Conv2D)             (None, 192, 256, 26  3978        ['activation_85[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 192, 256, 26  3978        ['activation_88[0][0]']
#                                 )
#
#  batch_normalization_114 (Batch  (None, 192, 256, 26  78         ['conv2d_77[0][0]']
#  Normalization)                 )
#
#  batch_normalization_118 (Batch  (None, 192, 256, 26  78         ['conv2d_80[0][0]']
#  Normalization)                 )
#
#  activation_86 (Activation)     (None, 192, 256, 26  0           ['batch_normalization_114[0][0]']
#                                 )
#
#  activation_89 (Activation)     (None, 192, 256, 26  0           ['batch_normalization_118[0][0]']
#                                 )
#
#  concatenate_22 (Concatenate)   (None, 192, 256, 51  0           ['activation_84[0][0]',
#                                 )                                 'activation_85[0][0]',
#                                                                   'activation_86[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 192, 256, 51  0           ['activation_87[0][0]',
#                                 )                                 'activation_88[0][0]',
#                                                                   'activation_89[0][0]']
#
#  batch_normalization_115 (Batch  (None, 192, 256, 51  204        ['concatenate_22[0][0]']
#  Normalization)                 )
#
#  batch_normalization_119 (Batch  (None, 192, 256, 51  204        ['concatenate_23[0][0]']
#  Normalization)                 )
#
#  add_19 (Add)                   (None, 192, 256, 51  0           ['batch_normalization_115[0][0]',
#                                 )                                 'batch_normalization_119[0][0]']
#
#  activation_90 (Activation)     (None, 192, 256, 51  0           ['add_19[0][0]']
#                                 )
#
#  batch_normalization_120 (Batch  (None, 192, 256, 51  204        ['activation_90[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 96, 128, 51)  0          ['batch_normalization_120[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 96, 128, 17)  7803        ['max_pooling2d_4[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 96, 128, 17)  7803        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_133 (Batch  (None, 96, 128, 17)  51         ['conv2d_89[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 96, 128, 17)  51         ['conv2d_92[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 96, 128, 17)  0           ['batch_normalization_133[0][0]']
#
#  activation_102 (Activation)    (None, 96, 128, 17)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 96, 128, 35)  5355        ['activation_99[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 96, 128, 35)  5355        ['activation_102[0][0]']
#
#  batch_normalization_134 (Batch  (None, 96, 128, 35)  105        ['conv2d_90[0][0]']
#  Normalization)
#
#  batch_normalization_138 (Batch  (None, 96, 128, 35)  105        ['conv2d_93[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 96, 128, 35)  0           ['batch_normalization_134[0][0]']
#
#  activation_103 (Activation)    (None, 96, 128, 35)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 96, 128, 53)  16695       ['activation_100[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 96, 128, 53)  16695       ['activation_103[0][0]']
#
#  batch_normalization_135 (Batch  (None, 96, 128, 53)  159        ['conv2d_91[0][0]']
#  Normalization)
#
#  batch_normalization_139 (Batch  (None, 96, 128, 53)  159        ['conv2d_94[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 96, 128, 53)  0           ['batch_normalization_135[0][0]']
#
#  activation_104 (Activation)    (None, 96, 128, 53)  0           ['batch_normalization_139[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 96, 128, 105  0           ['activation_99[0][0]',
#                                 )                                 'activation_100[0][0]',
#                                                                   'activation_101[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 96, 128, 105  0           ['activation_102[0][0]',
#                                 )                                 'activation_103[0][0]',
#                                                                   'activation_104[0][0]']
#
#  batch_normalization_136 (Batch  (None, 96, 128, 105  420        ['concatenate_24[0][0]']
#  Normalization)                 )
#
#  batch_normalization_140 (Batch  (None, 96, 128, 105  420        ['concatenate_25[0][0]']
#  Normalization)                 )
#
#  add_24 (Add)                   (None, 96, 128, 105  0           ['batch_normalization_136[0][0]',
#                                 )                                 'batch_normalization_140[0][0]']
#
#  activation_105 (Activation)    (None, 96, 128, 105  0           ['add_24[0][0]']
#                                 )
#
#  batch_normalization_141 (Batch  (None, 96, 128, 105  420        ['activation_105[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 48, 64, 105)  0          ['batch_normalization_141[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 48, 64, 35)   33075       ['max_pooling2d_5[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 48, 64, 35)   33075       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_151 (Batch  (None, 48, 64, 35)  105         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_155 (Batch  (None, 48, 64, 35)  105         ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 48, 64, 35)   0           ['batch_normalization_151[0][0]']
#
#  activation_115 (Activation)    (None, 48, 64, 35)   0           ['batch_normalization_155[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 48, 64, 71)   22365       ['activation_112[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 48, 64, 71)   22365       ['activation_115[0][0]']
#
#  batch_normalization_152 (Batch  (None, 48, 64, 71)  213         ['conv2d_102[0][0]']
#  Normalization)
#
#  batch_normalization_156 (Batch  (None, 48, 64, 71)  213         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 48, 64, 71)   0           ['batch_normalization_152[0][0]']
#
#  activation_116 (Activation)    (None, 48, 64, 71)   0           ['batch_normalization_156[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 48, 64, 106)  67734       ['activation_113[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 48, 64, 106)  67734       ['activation_116[0][0]']
#
#  batch_normalization_153 (Batch  (None, 48, 64, 106)  318        ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_157 (Batch  (None, 48, 64, 106)  318        ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 48, 64, 106)  0           ['batch_normalization_153[0][0]']
#
#  activation_117 (Activation)    (None, 48, 64, 106)  0           ['batch_normalization_157[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 48, 64, 212)  0           ['activation_112[0][0]',
#                                                                   'activation_113[0][0]',
#                                                                   'activation_114[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 48, 64, 212)  0           ['activation_115[0][0]',
#                                                                   'activation_116[0][0]',
#                                                                   'activation_117[0][0]']
#
#  batch_normalization_154 (Batch  (None, 48, 64, 212)  848        ['concatenate_26[0][0]']
#  Normalization)
#
#  batch_normalization_158 (Batch  (None, 48, 64, 212)  848        ['concatenate_27[0][0]']
#  Normalization)
#
#  add_28 (Add)                   (None, 48, 64, 212)  0           ['batch_normalization_154[0][0]',
#                                                                   'batch_normalization_158[0][0]']
#
#  activation_118 (Activation)    (None, 48, 64, 212)  0           ['add_28[0][0]']
#
#  batch_normalization_159 (Batch  (None, 48, 64, 212)  848        ['activation_118[0][0]']
#  Normalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 24, 32, 212)  0          ['batch_normalization_159[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 24, 32, 71)   135468      ['max_pooling2d_6[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 24, 32, 71)   135468      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_166 (Batch  (None, 24, 32, 71)  213         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_170 (Batch  (None, 24, 32, 71)  213         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_166[0][0]']
#
#  activation_126 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_170[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_123[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_126[0][0]']
#
#  batch_normalization_167 (Batch  (None, 24, 32, 142)  426        ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_171 (Batch  (None, 24, 32, 142)  426        ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_167[0][0]']
#
#  activation_127 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_124[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_127[0][0]']
#
#  batch_normalization_168 (Batch  (None, 24, 32, 213)  639        ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_172 (Batch  (None, 24, 32, 213)  639        ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_168[0][0]']
#
#  activation_128 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_172[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 24, 32, 426)  0           ['activation_123[0][0]',
#                                                                   'activation_124[0][0]',
#                                                                   'activation_125[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 24, 32, 426)  0           ['activation_126[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_128[0][0]']
#
#  batch_normalization_169 (Batch  (None, 24, 32, 426)  1704       ['concatenate_28[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 24, 32, 426)  1704       ['concatenate_29[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 24, 32, 426)  0           ['batch_normalization_169[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  activation_129 (Activation)    (None, 24, 32, 426)  0           ['add_31[0][0]']
#
#  batch_normalization_174 (Batch  (None, 24, 32, 426)  1704       ['activation_129[0][0]']
#  Normalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 16, 426)  0          ['batch_normalization_174[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 12, 16, 142)  544428      ['max_pooling2d_7[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 12, 16, 142)  544428      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_178 (Batch  (None, 12, 16, 142)  426        ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 12, 16, 142)  426        ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 12, 16, 142)  0           ['batch_normalization_178[0][0]']
#
#  activation_135 (Activation)    (None, 12, 16, 142)  0           ['batch_normalization_182[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 12, 16, 284)  362952      ['activation_132[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 12, 16, 284)  362952      ['activation_135[0][0]']
#
#  batch_normalization_179 (Batch  (None, 12, 16, 284)  852        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 12, 16, 284)  852        ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 12, 16, 284)  0           ['batch_normalization_179[0][0]']
#
#  activation_136 (Activation)    (None, 12, 16, 284)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 12, 16, 427)  1091412     ['activation_133[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 12, 16, 427)  1091412     ['activation_136[0][0]']
#
#  batch_normalization_180 (Batch  (None, 12, 16, 427)  1281       ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 12, 16, 427)  1281       ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 12, 16, 427)  0           ['batch_normalization_180[0][0]']
#
#  activation_137 (Activation)    (None, 12, 16, 427)  0           ['batch_normalization_184[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 12, 16, 853)  0           ['activation_132[0][0]',
#                                                                   'activation_133[0][0]',
#                                                                   'activation_134[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 12, 16, 853)  0           ['activation_135[0][0]',
#                                                                   'activation_136[0][0]',
#                                                                   'activation_137[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 24, 32, 256)  981504      ['batch_normalization_174[0][0]']
#
#  batch_normalization_181 (Batch  (None, 12, 16, 853)  3412       ['concatenate_30[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 12, 16, 853)  3412       ['concatenate_31[0][0]']
#  Normalization)
#
#  conv2d_117 (Conv2D)            (None, 24, 32, 256)  109056      ['batch_normalization_174[0][0]']
#
#  batch_normalization_176 (Batch  (None, 24, 32, 256)  768        ['conv2d_118[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 12, 16, 853)  0           ['batch_normalization_181[0][0]',
#                                                                   'batch_normalization_185[0][0]']
#
#  batch_normalization_175 (Batch  (None, 24, 32, 256)  768        ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 24, 32, 256)  0           ['batch_normalization_176[0][0]']
#
#  activation_138 (Activation)    (None, 12, 16, 853)  0           ['add_33[0][0]']
#
#  add_32 (Add)                   (None, 24, 32, 256)  0           ['batch_normalization_175[0][0]',
#                                                                   'activation_130[0][0]']
#
#  batch_normalization_186 (Batch  (None, 12, 16, 853)  3412       ['activation_138[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 24, 32, 256)  0           ['add_32[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 24, 32, 256)  873728     ['batch_normalization_186[0][0]']
#  spose)
#
#  batch_normalization_177 (Batch  (None, 24, 32, 256)  1024       ['activation_131[0][0]']
#  Normalization)
#
#  concatenate_32 (Concatenate)   (None, 24, 32, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'batch_normalization_177[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 24, 32, 71)   327168      ['concatenate_32[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 24, 32, 71)   327168      ['concatenate_32[0][0]']
#
#  batch_normalization_187 (Batch  (None, 24, 32, 71)  213         ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_191 (Batch  (None, 24, 32, 71)  213         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_187[0][0]']
#
#  activation_142 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_139[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_142[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 48, 64, 128)  244224      ['batch_normalization_159[0][0]']
#
#  batch_normalization_188 (Batch  (None, 24, 32, 142)  426        ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_192 (Batch  (None, 24, 32, 142)  426        ['conv2d_129[0][0]']
#  Normalization)
#
#  conv2d_107 (Conv2D)            (None, 48, 64, 128)  27136       ['batch_normalization_159[0][0]']
#
#  batch_normalization_161 (Batch  (None, 48, 64, 128)  384        ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_188[0][0]']
#
#  activation_143 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_192[0][0]']
#
#  batch_normalization_160 (Batch  (None, 48, 64, 128)  384        ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 48, 64, 128)  0           ['batch_normalization_161[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_140[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_143[0][0]']
#
#  add_29 (Add)                   (None, 48, 64, 128)  0           ['batch_normalization_160[0][0]',
#                                                                   'activation_119[0][0]']
#
#  batch_normalization_189 (Batch  (None, 24, 32, 213)  639        ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_193 (Batch  (None, 24, 32, 213)  639        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 48, 64, 128)  0           ['add_29[0][0]']
#
#  activation_141 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_189[0][0]']
#
#  activation_144 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_193[0][0]']
#
#  batch_normalization_162 (Batch  (None, 48, 64, 128)  512        ['activation_120[0][0]']
#  Normalization)
#
#  concatenate_33 (Concatenate)   (None, 24, 32, 426)  0           ['activation_139[0][0]',
#                                                                   'activation_140[0][0]',
#                                                                   'activation_141[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 24, 32, 426)  0           ['activation_142[0][0]',
#                                                                   'activation_143[0][0]',
#                                                                   'activation_144[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 48, 64, 128)  147456      ['batch_normalization_162[0][0]']
#
#  batch_normalization_190 (Batch  (None, 24, 32, 426)  1704       ['concatenate_33[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 24, 32, 426)  1704       ['concatenate_34[0][0]']
#  Normalization)
#
#  conv2d_109 (Conv2D)            (None, 48, 64, 128)  16384       ['batch_normalization_162[0][0]']
#
#  batch_normalization_164 (Batch  (None, 48, 64, 128)  384        ['conv2d_110[0][0]']
#  Normalization)
#
#  add_34 (Add)                   (None, 24, 32, 426)  0           ['batch_normalization_190[0][0]',
#                                                                   'batch_normalization_194[0][0]']
#
#  batch_normalization_163 (Batch  (None, 48, 64, 128)  384        ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 48, 64, 128)  0           ['batch_normalization_164[0][0]']
#
#  activation_145 (Activation)    (None, 24, 32, 426)  0           ['add_34[0][0]']
#
#  add_30 (Add)                   (None, 48, 64, 128)  0           ['batch_normalization_163[0][0]',
#                                                                   'activation_121[0][0]']
#
#  batch_normalization_195 (Batch  (None, 24, 32, 426)  1704       ['activation_145[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 48, 64, 128)  0           ['add_30[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 96, 128, 64)  60480       ['batch_normalization_141[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 48, 64, 128)  218240     ['batch_normalization_195[0][0]']
#  spose)
#
#  batch_normalization_165 (Batch  (None, 48, 64, 128)  512        ['activation_122[0][0]']
#  Normalization)
#
#  conv2d_95 (Conv2D)             (None, 96, 128, 64)  6720        ['batch_normalization_141[0][0]']
#
#  batch_normalization_143 (Batch  (None, 96, 128, 64)  192        ['conv2d_96[0][0]']
#  Normalization)
# ...
# 31/31 [==============================] - 5s 180ms/step
# Jacard Index : 0.09829215994380681
# Dice Coefficient : 0.1560124888579685
# ***********************************************
# Jacard Index improved from 0.08417337412892952 to 0.09829215994380681
# ***********************************************
# Epoch : 3
# 123/123 [==============================] - 72s 584ms/step - loss: 0.7089 - dice_coef: 0.2487 - jacard: 0.1445 - accuracy: 0.7470
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.18074599075898562
# Dice Coefficient : 0.2849344715311313
# ***********************************************
# Jacard Index improved from 0.09829215994380681 to 0.18074599075898562
# ***********************************************
# Epoch : 4
# 123/123 [==============================] - 72s 582ms/step - loss: 0.6981 - dice_coef: 0.2628 - jacard: 0.1540 - accuracy: 0.7990
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.16298473371318356
# Dice Coefficient : 0.25854585929054974
# Epoch : 5
# 123/123 [==============================] - 72s 583ms/step - loss: 0.7014 - dice_coef: 0.2608 - jacard: 0.1525 - accuracy: 0.8045
# 31/31 [==============================] - 5s 180ms/step
# Jacard Index : 0.14171808715216638
# Dice Coefficient : 0.23047623194019684
# Epoch : 6
# 123/123 [==============================] - 72s 585ms/step - loss: 0.6861 - dice_coef: 0.2760 - jacard: 0.1630 - accuracy: 0.8331
# 31/31 [==============================] - 5s 180ms/step
# Jacard Index : 0.2495060341046127
# Dice Coefficient : 0.36445230991074107
# ***********************************************
# Jacard Index improved from 0.18074599075898562 to 0.2495060341046127
# ***********************************************
# Epoch : 7
# 123/123 [==============================] - 72s 584ms/step - loss: 0.6756 - dice_coef: 0.2871 - jacard: 0.1703 - accuracy: 0.8558
# 31/31 [==============================] - 5s 180ms/step
# Jacard Index : 0.1792848738670343
# Dice Coefficient : 0.27798073549820534
# Epoch : 8
# 123/123 [==============================] - 72s 582ms/step - loss: 0.6718 - dice_coef: 0.2954 - jacard: 0.1770 - accuracy: 0.8733
# 31/31 [==============================] - 5s 180ms/step
# Jacard Index : 0.19103053937116865
# Dice Coefficient : 0.29224416874777215
# Epoch : 9
# 123/123 [==============================] - 72s 582ms/step - loss: 0.6613 - dice_coef: 0.3077 - jacard: 0.1853 - accuracy: 0.8868
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.2888443416695542
# Dice Coefficient : 0.3892417745531737
# ***********************************************
# Jacard Index improved from 0.2495060341046127 to 0.2888443416695542
# ***********************************************
# Epoch : 10
# 123/123 [==============================] - 72s 583ms/step - loss: 0.6517 - dice_coef: 0.3208 - jacard: 0.1938 - accuracy: 0.8966
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.32007594184256283
# Dice Coefficient : 0.43012218462043433
# ***********************************************
# Jacard Index improved from 0.2888443416695542 to 0.32007594184256283
# ***********************************************
# Epoch : 11
# 123/123 [==============================] - 72s 582ms/step - loss: 0.6402 - dice_coef: 0.3346 - jacard: 0.2040 - accuracy: 0.9130
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.33010806122634506
# Dice Coefficient : 0.44783682168896616
# ***********************************************
# Jacard Index improved from 0.32007594184256283 to 0.33010806122634506
# ***********************************************
# Epoch : 12
# 123/123 [==============================] - 71s 581ms/step - loss: 0.6253 - dice_coef: 0.3528 - jacard: 0.2170 - accuracy: 0.9226
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.22435533681599487
# Dice Coefficient : 0.3291961231483013
# Epoch : 13
# 123/123 [==============================] - 72s 581ms/step - loss: 0.6251 - dice_coef: 0.3583 - jacard: 0.2220 - accuracy: 0.9257
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.29463119893178497
# Dice Coefficient : 0.4112195386890601
# Epoch : 14
# 123/123 [==============================] - 72s 582ms/step - loss: 0.6204 - dice_coef: 0.3659 - jacard: 0.2281 - accuracy: 0.9296
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.4288814410983852
# Dice Coefficient : 0.5541279891442644
# ***********************************************
# Jacard Index improved from 0.33010806122634506 to 0.4288814410983852
# ***********************************************
# Epoch : 15
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5941 - dice_coef: 0.3921 - jacard: 0.2473 - accuracy: 0.9443
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.5027458923170567
# Dice Coefficient : 0.6179650126678116
# ***********************************************
# Jacard Index improved from 0.4288814410983852 to 0.5027458923170567
# ***********************************************
# Epoch : 16
# 123/123 [==============================] - 72s 581ms/step - loss: 0.5980 - dice_coef: 0.3949 - jacard: 0.2492 - accuracy: 0.9431
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.3697229737800428
# Dice Coefficient : 0.4751660083049493
# Epoch : 17
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5902 - dice_coef: 0.4034 - jacard: 0.2562 - accuracy: 0.9479
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.5204413620577217
# Dice Coefficient : 0.6324954938481993
# ***********************************************
# Jacard Index improved from 0.5027458923170567 to 0.5204413620577217
# ***********************************************
# Epoch : 18
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5731 - dice_coef: 0.4237 - jacard: 0.2716 - accuracy: 0.9564
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.35387395457671666
# Dice Coefficient : 0.4403554931831656
# Epoch : 19
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5677 - dice_coef: 0.4342 - jacard: 0.2797 - accuracy: 0.9579
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.5368893877046246
# Dice Coefficient : 0.6320624061984881
# ***********************************************
# Jacard Index improved from 0.5204413620577217 to 0.5368893877046246
# ***********************************************
# Epoch : 20
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5668 - dice_coef: 0.4349 - jacard: 0.2809 - accuracy: 0.9589
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.45056187573264184
# Dice Coefficient : 0.5410288031231083
# Epoch : 21
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5667 - dice_coef: 0.4403 - jacard: 0.2854 - accuracy: 0.9595
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.43575248438689196
# Dice Coefficient : 0.5361625022998759
# Epoch : 22
# 123/123 [==============================] - 72s 584ms/step - loss: 0.5531 - dice_coef: 0.4539 - jacard: 0.2959 - accuracy: 0.9645
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.5519632038475596
# Dice Coefficient : 0.6587869633258923
# ***********************************************
# Jacard Index improved from 0.5368893877046246 to 0.5519632038475596
# ***********************************************
# Epoch : 23
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5443 - dice_coef: 0.4651 - jacard: 0.3054 - accuracy: 0.9688
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.542381734904838
# Dice Coefficient : 0.6440640656611264
# Epoch : 24
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5388 - dice_coef: 0.4689 - jacard: 0.3085 - accuracy: 0.9712
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.2671845720339732
# Dice Coefficient : 0.3357717890252617
# Epoch : 25
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5503 - dice_coef: 0.4614 - jacard: 0.3029 - accuracy: 0.9679
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.4460247760417617
# Dice Coefficient : 0.527047629631199
# Epoch : 26
# 123/123 [==============================] - 72s 585ms/step - loss: 0.5316 - dice_coef: 0.4823 - jacard: 0.3197 - accuracy: 0.9732
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.5769073710826522
# Dice Coefficient : 0.668828111559614
# ***********************************************
# Jacard Index improved from 0.5519632038475596 to 0.5769073710826522
# ***********************************************
# Epoch : 27
# 123/123 [==============================] - 72s 584ms/step - loss: 0.5298 - dice_coef: 0.4833 - jacard: 0.3210 - accuracy: 0.9756
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.565541550648375
# Dice Coefficient : 0.6529081000911826
# Epoch : 28
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5210 - dice_coef: 0.4909 - jacard: 0.3277 - accuracy: 0.9779
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.5583649329223485
# Dice Coefficient : 0.6628011740415899
# Epoch : 29
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5260 - dice_coef: 0.4891 - jacard: 0.3257 - accuracy: 0.9769
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.6601545545841838
# Dice Coefficient : 0.7405425753543409
# ***********************************************
# Jacard Index improved from 0.5769073710826522 to 0.6601545545841838
# ***********************************************
# Epoch : 30
# 123/123 [==============================] - 72s 585ms/step - loss: 0.5231 - dice_coef: 0.4929 - jacard: 0.3294 - accuracy: 0.9789
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.6783456310934137
# Dice Coefficient : 0.7720643543799718
# ***********************************************
# Jacard Index improved from 0.6601545545841838 to 0.6783456310934137
# ***********************************************
# Epoch : 31
# 123/123 [==============================] - 72s 584ms/step - loss: 0.5320 - dice_coef: 0.4849 - jacard: 0.3228 - accuracy: 0.9762
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.6456580194626669
# Dice Coefficient : 0.7338521603074816
# Epoch : 32
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5180 - dice_coef: 0.5004 - jacard: 0.3360 - accuracy: 0.9808
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.7096375407090197
# Dice Coefficient : 0.7815512734054095
# ***********************************************
# Jacard Index improved from 0.6783456310934137 to 0.7096375407090197
# ***********************************************
# Epoch : 33
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5109 - dice_coef: 0.5068 - jacard: 0.3411 - accuracy: 0.9823
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.6422388272055634
# Dice Coefficient : 0.7205853361442037
# Epoch : 34
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5088 - dice_coef: 0.5095 - jacard: 0.3432 - accuracy: 0.9833
# 31/31 [==============================] - 6s 182ms/step
# Jacard Index : 0.6920154402465218
# Dice Coefficient : 0.7694104268655884
# Epoch : 35
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5139 - dice_coef: 0.5043 - jacard: 0.3392 - accuracy: 0.9817
# 31/31 [==============================] - 6s 182ms/step
# Jacard Index : 0.5251335274243506
# Dice Coefficient : 0.6174992003782395
# Epoch : 36
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5155 - dice_coef: 0.5039 - jacard: 0.3392 - accuracy: 0.9823
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.7181907375712266
# Dice Coefficient : 0.7861273904965177
# ***********************************************
# Jacard Index improved from 0.7096375407090197 to 0.7181907375712266
# ***********************************************
# Epoch : 37
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5082 - dice_coef: 0.5108 - jacard: 0.3449 - accuracy: 0.9842
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.6735561852436648
# Dice Coefficient : 0.7447004982035303
# Epoch : 38
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5021 - dice_coef: 0.5171 - jacard: 0.3504 - accuracy: 0.9866
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.5689401674347981
# Dice Coefficient : 0.6458862090693929
# Epoch : 39
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5044 - dice_coef: 0.5151 - jacard: 0.3487 - accuracy: 0.9856
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.687706647166588
# Dice Coefficient : 0.7685882953566202
# Epoch : 40
# 123/123 [==============================] - 72s 581ms/step - loss: 0.5137 - dice_coef: 0.5038 - jacard: 0.3393 - accuracy: 0.9829
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.6670776655770962
# Dice Coefficient : 0.751909184439267
# Epoch : 41
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5092 - dice_coef: 0.5114 - jacard: 0.3457 - accuracy: 0.9845
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.7252272968390959
# Dice Coefficient : 0.7911400120175872
# ***********************************************
# Jacard Index improved from 0.7181907375712266 to 0.7252272968390959
# ***********************************************
# Epoch : 42
# 123/123 [==============================] - 72s 583ms/step - loss: 0.5013 - dice_coef: 0.5174 - jacard: 0.3508 - accuracy: 0.9870
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.6977903572850187
# Dice Coefficient : 0.7709221953266339
# Epoch : 43
# 123/123 [==============================] - 72s 583ms/step - loss: 0.4990 - dice_coef: 0.5203 - jacard: 0.3530 - accuracy: 0.9871
# 31/31 [==============================] - 6s 183ms/step
# Jacard Index : 0.6594033659178093
# Dice Coefficient : 0.7269602368374776
# Epoch : 44
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5015 - dice_coef: 0.5192 - jacard: 0.3527 - accuracy: 0.9886
# 31/31 [==============================] - 6s 184ms/step
# Jacard Index : 0.7247729991807432
# Dice Coefficient : 0.7911493123917553
# Epoch : 45
# 123/123 [==============================] - 72s 583ms/step - loss: 0.4992 - dice_coef: 0.5207 - jacard: 0.3538 - accuracy: 0.9885
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.7638170918460115
# Dice Coefficient : 0.8216860657302598
# ***********************************************
# Jacard Index improved from 0.7252272968390959 to 0.7638170918460115
# ***********************************************
# Epoch : 46
# 123/123 [==============================] - 72s 584ms/step - loss: 0.4975 - dice_coef: 0.5224 - jacard: 0.3554 - accuracy: 0.9892
# 31/31 [==============================] - 5s 181ms/step
# Jacard Index : 0.7499711457175006
# Dice Coefficient : 0.8078691059152957
# Epoch : 47
# 123/123 [==============================] - 72s 583ms/step - loss: 0.4957 - dice_coef: 0.5233 - jacard: 0.3562 - accuracy: 0.9901
# 31/31 [==============================] - 6s 182ms/step
# Jacard Index : 0.7038508683457337
# Dice Coefficient : 0.777746141319043
# Epoch : 48
# 123/123 [==============================] - 72s 582ms/step - loss: 0.4961 - dice_coef: 0.5230 - jacard: 0.3561 - accuracy: 0.9892
# 31/31 [==============================] - 6s 184ms/step
# Jacard Index : 0.7266167014758479
# Dice Coefficient : 0.7959841402563193
# Epoch : 49
# 123/123 [==============================] - 72s 582ms/step - loss: 0.4979 - dice_coef: 0.5192 - jacard: 0.3527 - accuracy: 0.9881
# 31/31 [==============================] - 5s 180ms/step
# Jacard Index : 0.7449464433066263
# Dice Coefficient : 0.810286729806424
# Epoch : 50
# 123/123 [==============================] - 72s 582ms/step - loss: 0.5021 - dice_coef: 0.5197 - jacard: 0.3531 - accuracy: 0.9873
# 31/31 [==============================] - 6s 182ms/step
# Jacard Index : 0.41664401117330235
# Dice Coefficient : 0.49008551918854826

# %% [markdown]
# Ranked #1 on Medical Image Segmentation on ISBI 2012 EM Segmentation

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 192, 256, 3  0           []
#                                 )]
#
#  conv2d_75 (Conv2D)             (None, 192, 256, 8)  216         ['input_2[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 192, 256, 8)  216         ['input_2[0][0]']
#
#  batch_normalization_112 (Batch  (None, 192, 256, 8)  24         ['conv2d_75[0][0]']
#  Normalization)
#
#  batch_normalization_116 (Batch  (None, 192, 256, 8)  24         ['conv2d_78[0][0]']
#  Normalization)
#
#  activation_84 (Activation)     (None, 192, 256, 8)  0           ['batch_normalization_112[0][0]']
#
#  activation_87 (Activation)     (None, 192, 256, 8)  0           ['batch_normalization_116[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 192, 256, 17  1224        ['activation_84[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 192, 256, 17  1224        ['activation_87[0][0]']
#                                 )
#
#  batch_normalization_113 (Batch  (None, 192, 256, 17  51         ['conv2d_76[0][0]']
#  Normalization)                 )
#
#  batch_normalization_117 (Batch  (None, 192, 256, 17  51         ['conv2d_79[0][0]']
#  Normalization)                 )
#
#  activation_85 (Activation)     (None, 192, 256, 17  0           ['batch_normalization_113[0][0]']
#                                 )
#
#  activation_88 (Activation)     (None, 192, 256, 17  0           ['batch_normalization_117[0][0]']
#                                 )
#
#  conv2d_77 (Conv2D)             (None, 192, 256, 26  3978        ['activation_85[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 192, 256, 26  3978        ['activation_88[0][0]']
#                                 )
#
#  batch_normalization_114 (Batch  (None, 192, 256, 26  78         ['conv2d_77[0][0]']
#  Normalization)                 )
#
#  batch_normalization_118 (Batch  (None, 192, 256, 26  78         ['conv2d_80[0][0]']
#  Normalization)                 )
#
#  activation_86 (Activation)     (None, 192, 256, 26  0           ['batch_normalization_114[0][0]']
#                                 )
#
#  activation_89 (Activation)     (None, 192, 256, 26  0           ['batch_normalization_118[0][0]']
#                                 )
#
#  concatenate_22 (Concatenate)   (None, 192, 256, 51  0           ['activation_84[0][0]',
#                                 )                                 'activation_85[0][0]',
#                                                                   'activation_86[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 192, 256, 51  0           ['activation_87[0][0]',
#                                 )                                 'activation_88[0][0]',
#                                                                   'activation_89[0][0]']
#
#  batch_normalization_115 (Batch  (None, 192, 256, 51  204        ['concatenate_22[0][0]']
#  Normalization)                 )
#
#  batch_normalization_119 (Batch  (None, 192, 256, 51  204        ['concatenate_23[0][0]']
#  Normalization)                 )
#
#  add_19 (Add)                   (None, 192, 256, 51  0           ['batch_normalization_115[0][0]',
#                                 )                                 'batch_normalization_119[0][0]']
#
#  activation_90 (Activation)     (None, 192, 256, 51  0           ['add_19[0][0]']
#                                 )
#
#  batch_normalization_120 (Batch  (None, 192, 256, 51  204        ['activation_90[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 96, 128, 51)  0          ['batch_normalization_120[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 96, 128, 17)  7803        ['max_pooling2d_4[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 96, 128, 17)  7803        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_133 (Batch  (None, 96, 128, 17)  51         ['conv2d_89[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 96, 128, 17)  51         ['conv2d_92[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 96, 128, 17)  0           ['batch_normalization_133[0][0]']
#
#  activation_102 (Activation)    (None, 96, 128, 17)  0           ['batch_normalization_137[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 96, 128, 35)  5355        ['activation_99[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 96, 128, 35)  5355        ['activation_102[0][0]']
#
#  batch_normalization_134 (Batch  (None, 96, 128, 35)  105        ['conv2d_90[0][0]']
#  Normalization)
#
#  batch_normalization_138 (Batch  (None, 96, 128, 35)  105        ['conv2d_93[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 96, 128, 35)  0           ['batch_normalization_134[0][0]']
#
#  activation_103 (Activation)    (None, 96, 128, 35)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 96, 128, 53)  16695       ['activation_100[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 96, 128, 53)  16695       ['activation_103[0][0]']
#
#  batch_normalization_135 (Batch  (None, 96, 128, 53)  159        ['conv2d_91[0][0]']
#  Normalization)
#
#  batch_normalization_139 (Batch  (None, 96, 128, 53)  159        ['conv2d_94[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 96, 128, 53)  0           ['batch_normalization_135[0][0]']
#
#  activation_104 (Activation)    (None, 96, 128, 53)  0           ['batch_normalization_139[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 96, 128, 105  0           ['activation_99[0][0]',
#                                 )                                 'activation_100[0][0]',
#                                                                   'activation_101[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 96, 128, 105  0           ['activation_102[0][0]',
#                                 )                                 'activation_103[0][0]',
#                                                                   'activation_104[0][0]']
#
#  batch_normalization_136 (Batch  (None, 96, 128, 105  420        ['concatenate_24[0][0]']
#  Normalization)                 )
#
#  batch_normalization_140 (Batch  (None, 96, 128, 105  420        ['concatenate_25[0][0]']
#  Normalization)                 )
#
#  add_24 (Add)                   (None, 96, 128, 105  0           ['batch_normalization_136[0][0]',
#                                 )                                 'batch_normalization_140[0][0]']
#
#  activation_105 (Activation)    (None, 96, 128, 105  0           ['add_24[0][0]']
#                                 )
#
#  batch_normalization_141 (Batch  (None, 96, 128, 105  420        ['activation_105[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 48, 64, 105)  0          ['batch_normalization_141[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 48, 64, 35)   33075       ['max_pooling2d_5[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 48, 64, 35)   33075       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_151 (Batch  (None, 48, 64, 35)  105         ['conv2d_101[0][0]']
#  Normalization)
#
#  batch_normalization_155 (Batch  (None, 48, 64, 35)  105         ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_112 (Activation)    (None, 48, 64, 35)   0           ['batch_normalization_151[0][0]']
#
#  activation_115 (Activation)    (None, 48, 64, 35)   0           ['batch_normalization_155[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 48, 64, 71)   22365       ['activation_112[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 48, 64, 71)   22365       ['activation_115[0][0]']
#
#  batch_normalization_152 (Batch  (None, 48, 64, 71)  213         ['conv2d_102[0][0]']
#  Normalization)
#
#  batch_normalization_156 (Batch  (None, 48, 64, 71)  213         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 48, 64, 71)   0           ['batch_normalization_152[0][0]']
#
#  activation_116 (Activation)    (None, 48, 64, 71)   0           ['batch_normalization_156[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 48, 64, 106)  67734       ['activation_113[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 48, 64, 106)  67734       ['activation_116[0][0]']
#
#  batch_normalization_153 (Batch  (None, 48, 64, 106)  318        ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_157 (Batch  (None, 48, 64, 106)  318        ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 48, 64, 106)  0           ['batch_normalization_153[0][0]']
#
#  activation_117 (Activation)    (None, 48, 64, 106)  0           ['batch_normalization_157[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 48, 64, 212)  0           ['activation_112[0][0]',
#                                                                   'activation_113[0][0]',
#                                                                   'activation_114[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 48, 64, 212)  0           ['activation_115[0][0]',
#                                                                   'activation_116[0][0]',
#                                                                   'activation_117[0][0]']
#
#  batch_normalization_154 (Batch  (None, 48, 64, 212)  848        ['concatenate_26[0][0]']
#  Normalization)
#
#  batch_normalization_158 (Batch  (None, 48, 64, 212)  848        ['concatenate_27[0][0]']
#  Normalization)
#
#  add_28 (Add)                   (None, 48, 64, 212)  0           ['batch_normalization_154[0][0]',
#                                                                   'batch_normalization_158[0][0]']
#
#  activation_118 (Activation)    (None, 48, 64, 212)  0           ['add_28[0][0]']
#
#  batch_normalization_159 (Batch  (None, 48, 64, 212)  848        ['activation_118[0][0]']
#  Normalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 24, 32, 212)  0          ['batch_normalization_159[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 24, 32, 71)   135468      ['max_pooling2d_6[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 24, 32, 71)   135468      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_166 (Batch  (None, 24, 32, 71)  213         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_170 (Batch  (None, 24, 32, 71)  213         ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_166[0][0]']
#
#  activation_126 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_170[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_123[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_126[0][0]']
#
#  batch_normalization_167 (Batch  (None, 24, 32, 142)  426        ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_171 (Batch  (None, 24, 32, 142)  426        ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_167[0][0]']
#
#  activation_127 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_124[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_127[0][0]']
#
#  batch_normalization_168 (Batch  (None, 24, 32, 213)  639        ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_172 (Batch  (None, 24, 32, 213)  639        ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_168[0][0]']
#
#  activation_128 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_172[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 24, 32, 426)  0           ['activation_123[0][0]',
#                                                                   'activation_124[0][0]',
#                                                                   'activation_125[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 24, 32, 426)  0           ['activation_126[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_128[0][0]']
#
#  batch_normalization_169 (Batch  (None, 24, 32, 426)  1704       ['concatenate_28[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 24, 32, 426)  1704       ['concatenate_29[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 24, 32, 426)  0           ['batch_normalization_169[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  activation_129 (Activation)    (None, 24, 32, 426)  0           ['add_31[0][0]']
#
#  batch_normalization_174 (Batch  (None, 24, 32, 426)  1704       ['activation_129[0][0]']
#  Normalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 16, 426)  0          ['batch_normalization_174[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 12, 16, 142)  544428      ['max_pooling2d_7[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 12, 16, 142)  544428      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_178 (Batch  (None, 12, 16, 142)  426        ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 12, 16, 142)  426        ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 12, 16, 142)  0           ['batch_normalization_178[0][0]']
#
#  activation_135 (Activation)    (None, 12, 16, 142)  0           ['batch_normalization_182[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 12, 16, 284)  362952      ['activation_132[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 12, 16, 284)  362952      ['activation_135[0][0]']
#
#  batch_normalization_179 (Batch  (None, 12, 16, 284)  852        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_183 (Batch  (None, 12, 16, 284)  852        ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 12, 16, 284)  0           ['batch_normalization_179[0][0]']
#
#  activation_136 (Activation)    (None, 12, 16, 284)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 12, 16, 427)  1091412     ['activation_133[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 12, 16, 427)  1091412     ['activation_136[0][0]']
#
#  batch_normalization_180 (Batch  (None, 12, 16, 427)  1281       ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 12, 16, 427)  1281       ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 12, 16, 427)  0           ['batch_normalization_180[0][0]']
#
#  activation_137 (Activation)    (None, 12, 16, 427)  0           ['batch_normalization_184[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 12, 16, 853)  0           ['activation_132[0][0]',
#                                                                   'activation_133[0][0]',
#                                                                   'activation_134[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 12, 16, 853)  0           ['activation_135[0][0]',
#                                                                   'activation_136[0][0]',
#                                                                   'activation_137[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 24, 32, 256)  981504      ['batch_normalization_174[0][0]']
#
#  batch_normalization_181 (Batch  (None, 12, 16, 853)  3412       ['concatenate_30[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 12, 16, 853)  3412       ['concatenate_31[0][0]']
#  Normalization)
#
#  conv2d_117 (Conv2D)            (None, 24, 32, 256)  109056      ['batch_normalization_174[0][0]']
#
#  batch_normalization_176 (Batch  (None, 24, 32, 256)  768        ['conv2d_118[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 12, 16, 853)  0           ['batch_normalization_181[0][0]',
#                                                                   'batch_normalization_185[0][0]']
#
#  batch_normalization_175 (Batch  (None, 24, 32, 256)  768        ['conv2d_117[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 24, 32, 256)  0           ['batch_normalization_176[0][0]']
#
#  activation_138 (Activation)    (None, 12, 16, 853)  0           ['add_33[0][0]']
#
#  add_32 (Add)                   (None, 24, 32, 256)  0           ['batch_normalization_175[0][0]',
#                                                                   'activation_130[0][0]']
#
#  batch_normalization_186 (Batch  (None, 12, 16, 853)  3412       ['activation_138[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 24, 32, 256)  0           ['add_32[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 24, 32, 256)  873728     ['batch_normalization_186[0][0]']
#  spose)
#
#  batch_normalization_177 (Batch  (None, 24, 32, 256)  1024       ['activation_131[0][0]']
#  Normalization)
#
#  concatenate_32 (Concatenate)   (None, 24, 32, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'batch_normalization_177[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 24, 32, 71)   327168      ['concatenate_32[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 24, 32, 71)   327168      ['concatenate_32[0][0]']
#
#  batch_normalization_187 (Batch  (None, 24, 32, 71)  213         ['conv2d_125[0][0]']
#  Normalization)
#
#  batch_normalization_191 (Batch  (None, 24, 32, 71)  213         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_187[0][0]']
#
#  activation_142 (Activation)    (None, 24, 32, 71)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_139[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 24, 32, 142)  90738       ['activation_142[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 48, 64, 128)  244224      ['batch_normalization_159[0][0]']
#
#  batch_normalization_188 (Batch  (None, 24, 32, 142)  426        ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_192 (Batch  (None, 24, 32, 142)  426        ['conv2d_129[0][0]']
#  Normalization)
#
#  conv2d_107 (Conv2D)            (None, 48, 64, 128)  27136       ['batch_normalization_159[0][0]']
#
#  batch_normalization_161 (Batch  (None, 48, 64, 128)  384        ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_188[0][0]']
#
#  activation_143 (Activation)    (None, 24, 32, 142)  0           ['batch_normalization_192[0][0]']
#
#  batch_normalization_160 (Batch  (None, 48, 64, 128)  384        ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 48, 64, 128)  0           ['batch_normalization_161[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_140[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 24, 32, 213)  272214      ['activation_143[0][0]']
#
#  add_29 (Add)                   (None, 48, 64, 128)  0           ['batch_normalization_160[0][0]',
#                                                                   'activation_119[0][0]']
#
#  batch_normalization_189 (Batch  (None, 24, 32, 213)  639        ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_193 (Batch  (None, 24, 32, 213)  639        ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 48, 64, 128)  0           ['add_29[0][0]']
#
#  activation_141 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_189[0][0]']
#
#  activation_144 (Activation)    (None, 24, 32, 213)  0           ['batch_normalization_193[0][0]']
#
#  batch_normalization_162 (Batch  (None, 48, 64, 128)  512        ['activation_120[0][0]']
#  Normalization)
#
#  concatenate_33 (Concatenate)   (None, 24, 32, 426)  0           ['activation_139[0][0]',
#                                                                   'activation_140[0][0]',
#                                                                   'activation_141[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 24, 32, 426)  0           ['activation_142[0][0]',
#                                                                   'activation_143[0][0]',
#                                                                   'activation_144[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 48, 64, 128)  147456      ['batch_normalization_162[0][0]']
#
#  batch_normalization_190 (Batch  (None, 24, 32, 426)  1704       ['concatenate_33[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 24, 32, 426)  1704       ['concatenate_34[0][0]']
#  Normalization)
#
#  conv2d_109 (Conv2D)            (None, 48, 64, 128)  16384       ['batch_normalization_162[0][0]']
#
#  batch_normalization_164 (Batch  (None, 48, 64, 128)  384        ['conv2d_110[0][0]']
#  Normalization)
#
#  add_34 (Add)                   (None, 24, 32, 426)  0           ['batch_normalization_190[0][0]',
#                                                                   'batch_normalization_194[0][0]']
#
#  batch_normalization_163 (Batch  (None, 48, 64, 128)  384        ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 48, 64, 128)  0           ['batch_normalization_164[0][0]']
#
#  activation_145 (Activation)    (None, 24, 32, 426)  0           ['add_34[0][0]']
#
#  add_30 (Add)                   (None, 48, 64, 128)  0           ['batch_normalization_163[0][0]',
#                                                                   'activation_121[0][0]']
#
#  batch_normalization_195 (Batch  (None, 24, 32, 426)  1704       ['activation_145[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 48, 64, 128)  0           ['add_30[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 96, 128, 64)  60480       ['batch_normalization_141[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 48, 64, 128)  218240     ['batch_normalization_195[0][0]']
#  spose)
#
#  batch_normalization_165 (Batch  (None, 48, 64, 128)  512        ['activation_122[0][0]']
#  Normalization)
#
#  conv2d_95 (Conv2D)             (None, 96, 128, 64)  6720        ['batch_normalization_141[0][0]']
#
#  batch_normalization_143 (Batch  (None, 96, 128, 64)  192        ['conv2d_96[0][0]']
#  Normalization)
#
# ...
#                                 )
#
#  conv2d_139 (Conv2D)            (None, 96, 128, 53)  16695       ['activation_154[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 96, 128, 53)  16695       ['activation_157[0][0]']
#
#  add_22 (Add)                   (None, 192, 256, 32  0           ['batch_normalization_127[0][0]',
#                                 )                                 'activation_95[0][0]']
#
#  batch_normalization_207 (Batch  (None, 96, 128, 53)  159        ['conv2d_139[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 96, 128, 53)  159        ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_96 (Activation)     (None, 192, 256, 32  0           ['add_22[0][0]']
#                                 )
#
#  activation_155 (Activation)    (None, 96, 128, 53)  0           ['batch_normalization_207[0][0]']
#
#  activation_158 (Activation)    (None, 96, 128, 53)  0           ['batch_normalization_211[0][0]']
#
#  batch_normalization_129 (Batch  (None, 192, 256, 32  128        ['activation_96[0][0]']
#  Normalization)                 )
#
#  concatenate_39 (Concatenate)   (None, 96, 128, 105  0           ['activation_153[0][0]',
#                                 )                                 'activation_154[0][0]',
#                                                                   'activation_155[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 96, 128, 105  0           ['activation_156[0][0]',
#                                 )                                 'activation_157[0][0]',
#                                                                   'activation_158[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 192, 256, 32  9216        ['batch_normalization_129[0][0]']
#                                 )
#
#  batch_normalization_208 (Batch  (None, 96, 128, 105  420        ['concatenate_39[0][0]']
#  Normalization)                 )
#
#  batch_normalization_212 (Batch  (None, 96, 128, 105  420        ['concatenate_40[0][0]']
#  Normalization)                 )
#
#  conv2d_87 (Conv2D)             (None, 192, 256, 32  1024        ['batch_normalization_129[0][0]']
#                                 )
#
#  batch_normalization_131 (Batch  (None, 192, 256, 32  96         ['conv2d_88[0][0]']
#  Normalization)                 )
#
#  add_36 (Add)                   (None, 96, 128, 105  0           ['batch_normalization_208[0][0]',
#                                 )                                 'batch_normalization_212[0][0]']
#
#  batch_normalization_130 (Batch  (None, 192, 256, 32  96         ['conv2d_87[0][0]']
#  Normalization)                 )
#
#  activation_97 (Activation)     (None, 192, 256, 32  0           ['batch_normalization_131[0][0]']
#                                 )
#
#  activation_159 (Activation)    (None, 96, 128, 105  0           ['add_36[0][0]']
#                                 )
#
#  add_23 (Add)                   (None, 192, 256, 32  0           ['batch_normalization_130[0][0]',
#                                 )                                 'activation_97[0][0]']
#
#  batch_normalization_213 (Batch  (None, 96, 128, 105  420        ['activation_159[0][0]']
#  Normalization)                 )
#
#  activation_98 (Activation)     (None, 192, 256, 32  0           ['add_23[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 192, 256, 32  13472      ['batch_normalization_213[0][0]']
#  spose)                         )
#
#  batch_normalization_132 (Batch  (None, 192, 256, 32  128        ['activation_98[0][0]']
#  Normalization)                 )
#
#  concatenate_41 (Concatenate)   (None, 192, 256, 64  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'batch_normalization_132[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 192, 256, 8)  4608        ['concatenate_41[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 192, 256, 8)  4608        ['concatenate_41[0][0]']
#
#  batch_normalization_214 (Batch  (None, 192, 256, 8)  24         ['conv2d_143[0][0]']
#  Normalization)
#
#  batch_normalization_218 (Batch  (None, 192, 256, 8)  24         ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 192, 256, 8)  0           ['batch_normalization_214[0][0]']
#
#  activation_163 (Activation)    (None, 192, 256, 8)  0           ['batch_normalization_218[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 192, 256, 17  1224        ['activation_160[0][0]']
#                                 )
#
#  conv2d_147 (Conv2D)            (None, 192, 256, 17  1224        ['activation_163[0][0]']
#                                 )
#
#  batch_normalization_215 (Batch  (None, 192, 256, 17  51         ['conv2d_144[0][0]']
#  Normalization)                 )
#
#  batch_normalization_219 (Batch  (None, 192, 256, 17  51         ['conv2d_147[0][0]']
#  Normalization)                 )
#
#  activation_161 (Activation)    (None, 192, 256, 17  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  activation_164 (Activation)    (None, 192, 256, 17  0           ['batch_normalization_219[0][0]']
#                                 )
#
#  conv2d_145 (Conv2D)            (None, 192, 256, 26  3978        ['activation_161[0][0]']
#                                 )
#
#  conv2d_148 (Conv2D)            (None, 192, 256, 26  3978        ['activation_164[0][0]']
#                                 )
#
#  batch_normalization_216 (Batch  (None, 192, 256, 26  78         ['conv2d_145[0][0]']
#  Normalization)                 )
#
#  batch_normalization_220 (Batch  (None, 192, 256, 26  78         ['conv2d_148[0][0]']
#  Normalization)                 )
#
#  activation_162 (Activation)    (None, 192, 256, 26  0           ['batch_normalization_216[0][0]']
#                                 )
#
#  activation_165 (Activation)    (None, 192, 256, 26  0           ['batch_normalization_220[0][0]']
#                                 )
#
#  concatenate_42 (Concatenate)   (None, 192, 256, 51  0           ['activation_160[0][0]',
#                                 )                                 'activation_161[0][0]',
#                                                                   'activation_162[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 192, 256, 51  0           ['activation_163[0][0]',
#                                 )                                 'activation_164[0][0]',
#                                                                   'activation_165[0][0]']
#
#  batch_normalization_217 (Batch  (None, 192, 256, 51  204        ['concatenate_42[0][0]']
#  Normalization)                 )
#
#  batch_normalization_221 (Batch  (None, 192, 256, 51  204        ['concatenate_43[0][0]']
#  Normalization)                 )
#
#  add_37 (Add)                   (None, 192, 256, 51  0           ['batch_normalization_217[0][0]',
#                                 )                                 'batch_normalization_221[0][0]']
#
#  activation_166 (Activation)    (None, 192, 256, 51  0           ['add_37[0][0]']
#                                 )
#
#  batch_normalization_222 (Batch  (None, 192, 256, 51  204        ['activation_166[0][0]']
#  Normalization)                 )
#
#  conv2d_149 (Conv2D)            (None, 192, 256, 1)  51          ['batch_normalization_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 192, 256, 1)  3          ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 192, 256, 1)  0           ['batch_normalization_223[0][0]']
#
# ==================================================================================================
# Total params: 10,069,928
# Trainable params: 10,040,524
# Non-trainable params: 29,404
# __________________________________________________________________________________________________

# %%
print("GG EZ NOOBS")
# Out:
# GG EZ NOOBS

# %%
evaluateModel(model, X_test, Y_test, 4)
# Out:
# 31/31 [==============================] - 6s 185ms/step
# Jacard Index : 0.41664401117330235
# Dice Coefficient : 0.49008551918854826
